# %% [markdown]
# # Jupyter Notebook
#
# This is a Jupyter Notebook, which is a basically just a super fancy Python shell.
#
# You may have "cells" that can either be text (like this one) or executable Python code. Notebooks are really nice because they allow you to rapidly develop Python code by writing small bits of code, testing their output, and moving on to the next bit; this interactive nature of the notebook is a huge plus to professional Python developers.
#
# It's also nice, because it's really easy to share your code with others and surround it with text to tell a story!
#
# # Colaboratory
# Colaboratory is a service provided by Google to take a Jupyter Notebook (a standard formay of a `.ipynb` file) and let users edit/run the code in the notebook for free!
#
# This notebook is write-protected so you are not able to edit the  notebook that the whole class will look at, but you are able to open up the notebook in "playground mode" which lets you make edits to a temporary copy of the notebook. If you want to save the changes you made to this notebook, you will have to follow the instructions when you try to save to copy the notebook to your Google Drive.
#
# # Setup
# Make sure you run the following cell(s) before trying to run any the following cells. You do not need to understand what they are doing, it's just a way to make sure there is a file we want to use stored on the computer running this notebook.

# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import imageio
import matplotlib

def save_file(url, file_name):
  r = requests.get(url)
  with open(file_name, 'wb') as f:
    f.write(r.content)
    
save_file('https://courses.cs.washington.edu/courses/cse163/19sp/files/section/05-23/corgi.png', 'corgi.png')
save_file('https://courses.cs.washington.edu/courses/cse163/19sp/files/section/05-23/coins.png', 'coins.png')

# %% [markdown]
# # Section Problems
#
# ## Problem 1) `edge_detection`
# Write a function named `edge_detection` that takes an `(n x m)` matrix representing a gray-scale image and performs a convolution using an edge detection kernel over the image. The result of the convolution should be returned as an `np array`.
#
# For edge detection we will use the `(3 x 3)` matrix shown below.
# ~~~~
#  [[-1, -1, -1],
#   [-1,  8, -1],
#   [-1, -1, -1]]
# ~~~~
#
# As a challenge, convince yourself why this kernel produces edge detection.

# %%
#Solution

# %%
img = imageio.imread('coins.png')
fig = plt.figure(figsize=(15, 15))
a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(img, cmap=plt.cm.gray)

a = fig.add_subplot(1, 2, 2)
img = edge_detection(img)
imgplot = plt.imshow(img, cmap=plt.cm.gray)

# %% [markdown]
# ##Problem 2)  `reweight_colors`
# Write a function named `reweight_colors` which takes an `(n, m, 3)` matrix representing a color image, and a `(3,)` weight vector and returns the image with the color reweighted by the corresponding factor in the weight vector. For example, if we gave the weight vector `[2, 1, 0]`, it would multiply every value in the red channel by 2, leave the green value unchanged, and set all the blue channel to have value 0. **Note that weight vectors must have integer values.**
#
# Index 0 of the weight vector corresponds to the weight factor of the red channel of the image, index 1 corresponds to the green channel, and index 2 corresponds to the blue channel.
#
# **You should not use any loops to solve this problem.**

# %%
# Solution

# %%
img = imageio.imread('corgi.png')[:, :, :3]
fig = plt.figure(figsize=(10, 5))
a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(img)

a = fig.add_subplot(1, 2, 2)
img = reweight_colors(img, np.array([2, 1, 0]))
imgplot = plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##Problem 3) `swap_colors`
# Write a function named `swap_colors` which takes an `(n, m, 3)` matrix representing a color image and returns the image with the color channels swapped. The image passed to `swap_colors` will be in standard **rgb** form where index 0 of dimension 3 in the image is the red channel, index 1 is green, and index 2 is blue. The resulting image should be in **gbr** form.
#
# **You should not use any loops to solve this problem**

# %%
# Solution

# %%
img = imageio.imread('corgi.png')[:, :, :3]
fig = plt.figure(figsize=(10, 5))
a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(img)

a = fig.add_subplot(1, 2, 2)
img = swap_colors(img)
imgplot = plt.imshow(img)
